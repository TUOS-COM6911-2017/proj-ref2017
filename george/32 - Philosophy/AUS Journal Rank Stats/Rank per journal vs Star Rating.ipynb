# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import difflib
## Stats on Output and Citation

# Load and clean the output file
aujour_or = pd.read_csv("2010AJR.csv")

aujour_or = aujour_or.drop(aujour_or.columns[[0]], axis=1)
aujour_or = aujour_or.drop(aujour_or.columns[[range(2,8)]], axis=1)


aujour_or = aujour_or.rename(columns = {"Title":"VolumeTitle"})
aujour_or["ISSN1"] = aujour_or.ISSN1.str.replace('X', '')
aujour_or["ISSN2"] = aujour_or.ISSN2.str.replace('X', '')
aujour_or["ISSN3"] = aujour_or.ISSN3.str.replace('X', '')
aujour_or["ISSN4"] = aujour_or.ISSN4.str.replace('X', '')
aujour_or["ISSN1"] = aujour_or.ISSN1.str.replace('-', '')
aujour_or["ISSN2"] = aujour_or.ISSN2.str.replace('-', '')
aujour_or["ISSN3"] = aujour_or.ISSN3.str.replace('-', '')
aujour_or["ISSN4"] = aujour_or.ISSN4.str.replace('-', '')
aujour_or
# Out:
#       Rank                                        VolumeTitle     ISSN1  \
# 0        C                           1913: a journal of forms  15489914
# 1        B                                            3CMedia  18326161
# 2        C    4OR: A Quarterly Journal of Operations Research  16194500
# 3        C           A St A: Advances in Statistical Analysis  18638171
# 4        A  AA files: annals of the Architectural Associat...  02616823
# 5        B                    AACE International Transactions  15287106
# 6        B                                       AACE Journal  15513696
# 7        C                        AACN Advanced Critical Care  15597768
# 8        C                                       AANA Journal  00946354
# 9        C                                      AAOHN Journal  08910162
# 10       A                                      AAPG Bulletin  01491423
# 11       C                                       AAPS Journal  15507416
# 12       B                                  AAPS PharmSciTech  15309932
# 13       C     Aarboeger for Nordisk Oldkyndighed og Historie   0084585
# 14       C           AASA Journal of Scholarship and Practice  19316569
# 15       B                 ABA Journal: the lawyer's magazine  07470088
# 16       A  Abacus: a Journal of Accounting and Business S...  00013072
# 17       C                                  Abdominal Imaging  09428925
# 18       C       Abhandlungen fuer die Kunde des Morgenlandes  05674980
# 19       C  Aboriginal and Islander Health Worker Journal:...  10373403
# 20       B  Aboriginal and Torres Strait Islander Studies ...  13227157
# 21       A                                 Aboriginal History  03148769
# 22       A                                  About Performance  13246089
# 23       B                      Abstract and Applied Analysis  10853375
# 24       C                                            Academe  01902946
# 25       C  Academia de Stiinte a Republicii Moldova. Bule...  10247696
# 26       C                           Academia Economic Papers   1018161
# 27       C  Academia Paedagogica Nyiregyhaziensis. Acta Ma...  17860091
# 28       C    Academiae Scientiarum Hungarica. Acta Zoologica  12178837
# 29       B                        Academic Emergency Medicine  10696563
# ...    ...                                                ...       ...
# 20682    C  Zielsprache Deutsch: die Zeitschrift fuer den ...  03415864
# 20683    C          Zimbabwe Journal of Agricultural Research  02511045
# 20684    C           Zimbabwe Journal of Educational Research  10133445
# 20685    C                        Zimbabwe Veterinary Journal  10161511
# 20686    B                                             Zinbvn  00845515
# 20687    C                                        Ziva Antika  05147727
# 20688    A  ZNT - Zeitschrift fuer Neues Testament: das ne...  14352249
# 20689    B                                        Zoo Biology  07333188
# 20690    C                                       Zoocriaderos  07987811
# 20691    C  Zoologica Poloniae: Archivum Societatis Zoolog...   0044510
# 20692    B                                  Zoologica Scripta  03003256
# 20693    A          Zoological Journal of the Linnean Society  00244082
# 20694    B       Zoological Science: an international journal  02890003
# 20695    C                                 Zoological Studies  10215506
# 20696    C                              Zoologichesky Zhurnal  00445134
# 20697    C  Zoologisch-Botanische Gesellschaft in Oesterre...  02521911
# 20698    B                              Zoologischer Anzeiger  00445231
# 20699    B                                            Zoology  09442006
# 20700    C                         Zoology in the Middle East  09397140
# 20701    B  Zoomorphology: an international journal of com...   0720213
# 20702    B                         Zoonoses and Public Health  18631959
# 20703    C  Zoosystematics and Evolution: Mitteilungen aus...  14351935
# 20704    C                                            Zootaxa  11755326
# 20705    C                              Zpravy Pamatkove Pece  12105538
# 20706    C                                     Zuchtungskunde  00445401
# 20707    C                                 Zuckmayer-Jahrbuch  14347865
# 20708    C                                       Zuowu Xuebao  04963490
# 20709    B                                         Zwingliana  02544407
# 20710    A             Zygon: journal of religion and science  05912385
# 20711    C   Zygote: the biology of gametes and early embryos  09671994
#
#           ISSN2     ISSN3     ISSN4
# 0           NaN       NaN       NaN
# 1       1445971       NaN       NaN
# 2      03908127       NaN       NaN
# 3       1863818  00026018       NaN
# 4           NaN       NaN       NaN
# 5           NaN       NaN       NaN
# 6           NaN       NaN       NaN
# 7      15597776  10790713       NaN
# 8           NaN       NaN       NaN
# 9           NaN       NaN       NaN
# 10     15589153       NaN       NaN
# 11          NaN       NaN       NaN
# 12          NaN       NaN       NaN
# 13          NaN       NaN       NaN
# 14      0898252       NaN       NaN
# 15          NaN       NaN       NaN
# 16     14676281       NaN       NaN
# 17     03642356       NaN       NaN
# 18          NaN       NaN       NaN
# 19          NaN       NaN       NaN
# 20          NaN       NaN       NaN
# 21          NaN       NaN       NaN
# 22          NaN       NaN       NaN
# 23     16870409       NaN       NaN
# 24          NaN       NaN       NaN
# 25     02363089       NaN       NaN
# 26          NaN       NaN       NaN
# 27     08660182       NaN       NaN
# 28     02367130  00017264       NaN
# 29     15532712       NaN       NaN
# ...         ...       ...       ...
# 20682       NaN       NaN       NaN
# 20683  00354813       NaN       NaN
# 20684       NaN       NaN       NaN
# 20685       NaN       NaN       NaN
# 20686       NaN       NaN       NaN
# 20687       NaN       NaN       NaN
# 20688       NaN       NaN       NaN
# 20689  10982361       NaN       NaN
# 20690       NaN       NaN       NaN
# 20691       NaN       NaN       NaN
# 20692  14636409       NaN       NaN
# 20693  10963642       NaN       NaN
# 20694       NaN       NaN       NaN
# 20695  00013943       NaN       NaN
# 20696  00138738       NaN       NaN
# 20697       NaN       NaN       NaN
# 20698  18732674  00445193       NaN
# 20699  18732720       NaN       NaN
# 20700       NaN       NaN       NaN
# 20701   1432234       NaN       NaN
# 20702  18632378  09311793  09314229
# 20703  18600743  02325519  03738493
# 20704  11755334       NaN       NaN
# 20705       NaN       NaN       NaN
# 20706       NaN       NaN       NaN
# 20707  01771183       NaN       NaN
# 20708       NaN       NaN       NaN
# 20709       NaN       NaN       NaN
# 20710  14679744       NaN       NaN
# 20711  14698730       NaN       NaN
#
# [20712 rows x 6 columns]

# %%
refcs_or = pd.read_csv("REF2014Data_output.csv")

refcs_or = refcs_or.drop(refcs_or.columns[[range(1,8)]], axis=1)
refcs_or = refcs_or.drop(refcs_or.columns[[range(2,7)]], axis=1)
refcs_or = refcs_or.drop(refcs_or.columns[3::], axis=1)
refcs_or["ISSN"] = refcs_or.ISSN.str.replace('X', '')
refcs_or["ISSN"] = refcs_or.ISSN.str.replace('-', '')

refcs_or
# Out:
#          UKPRN                                        VolumeTitle      ISSN
# 0     10007760            Proceedings of the Aristotelian Society  00667374
# 1     10007760                    Minds, Ethics, and Conditionals       NaN
# 2     10007760                                           Synthese  00397857
# 3     10007760                              Prospects for Meaning       NaN
# 4     10007760  Knowing How: Essays on Knowledge, Mind, and Ac...       NaN
# 5     10007760                     Essays on Anscombe's Intention       NaN
# 6     10007760  Reason, Faith and History: Philosophical Essay...       NaN
# 7     10007760                                         Dialectica  00122017
# 8     10007760                                         Axiomathes  11221151
# 9     10007760                     Journal of Philosophical Logic  15730433
# 10    10007760                                               Mind  14602113
# 11    10007760                              Journal of Philosophy   0022362
# 12    10007760                        The Philosophical Quarterly  00318094
# 13    10007760                       The Review of Symbolic Logic  17550203
# 14    10007760                                           Synthese  00397857
# 15    10007760                                           Synthese  00397857
# 16    10007760                              Philosophical Studies  00318116
# 17    10007760                              Philosophical Studies  00318116
# 18    10007760                                                NaN       NaN
# 19    10007760                                                NaN       NaN
# 20    10007760                 Australasian Journal of Philosophy  00048402
# 21    10007760                                           Synthese  00397857
# 22    10007760          Aristotelian Society Supplementary Volume  03097013
# 23    10007760           Royal Institute of Philosophy Supplement  13582461
# 24    10007760                                           Synthese  00397857
# 25    10007760                                                NaN       NaN
# 26    10007760          Aristotelian Society Supplementary Volume  03097013
# 27    10007760         Spinoza's 'Theological-Political Treatise'       NaN
# 28    10007760  Understanding Counterfactuals, Understanding C...       NaN
# 29    10007760                  The British Journal of Aesthetics  14682842
# ...        ...                                                ...       ...
# 2143  10007814                                          Abstracta  18079792
# 2144  10007814                                                NaN       NaN
# 2145  10007814              Nietzsche, Naturalism and Normativity       NaN
# 2146  10007814                               Health Care Analysis  10653058
# 2147  10007814                               Health Care Analysis  10653058
# 2148  10007814                                          Cognition  00100277
# 2149  10007814                              Philosophical Studies  00318116
# 2150  10007814                              Philosophical Studies  00318116
# 2151  10007814                     European Journal of Philosophy  09668373
# 2152  10007814                                                NaN       NaN
# 2153  10007814                                                NaN       NaN
# 2154  10007814                                                NaN       NaN
# 2155  10007814                    Nietzsche and Political Thought       NaN
# 2156  10005343                          The Journal of Philosophy   0022362
# 2157  10005343                The Philosophy of International Law       NaN
# 2158  10005343                               Ethical Perspectives  13700049
# 2159  10005343                                  Religious Studies  00344125
# 2160  10005343                                           Synthese  00397857
# 2161  10005343                                 Law and Philosophy  01675249
# 2162  10005343                      Journal of Applied Philosophy  02643758
# 2163  10005343                      Journal of Applied Philosophy  02643758
# 2164  10005343                                          Bioethics  14678519
# 2165  10005343                      Journal of Applied Philosophy  02643758
# 2166  10005343                                         Philosophy  00318191
# 2167  10005343                  Ethical Theory and Moral Practice  13862820
# 2168  10005343                                           Synthese  00397857
# 2169  10005343  Procreation and Parenthood: The Ethics of Bear...       NaN
# 2170  10005343           Philosophy and Phenomenological Research  19331592
# 2171  10005343                Forgiveness: Probing the Boundaries       NaN
# 2172  10005343                              Philosophers' Imprint   1533628
#
# [2173 rows x 3 columns]

# %%
ref = {}
for index, row in refcs_or.iterrows():
    indexs = index
    ref[index] = row["ISSN"]

# %%
ajourone = {}
for index, row in aujour_or.iterrows():
    ajourone[row["ISSN1"]] = row["Rank"]

len(ajourone)
# Out:
# 20712

# %%
ajourtwo = {}
for index, row in aujour_or.iterrows():
    ajourtwo[row["ISSN2"]] = row["Rank"]

len(ajourtwo)
# Out:
# 11416

# %%
ajourthree = {}
for index, row in aujour_or.iterrows():
    ajourthree[row["ISSN3"]] = row["Rank"]

len(ajourthree)
# Out:
# 1511

# %%
ajourfour = {}
for index, row in aujour_or.iterrows():
    ajourfour[row["ISSN4"]] = row["Rank"]

len(ajourfour)
# Out:
# 212

# %%
ranklistone = {}

for index in ref:
    for issn in ajourone:
        if issn == ref[index]:
            ranklistone[index] = ajourone[issn]

# %%
ranklisttwo = {}

for index in ref:
    for issn in ajourtwo:
        if issn == ref[index]:
            ranklisttwo[index] = ajourtwo[issn]

# %%
ranklistthree = {}

for index in ref:
    for issn in ajourthree:
        if issn == ref[index]:
            ranklistthree[index] = ajourthree[issn]

# %%
ranklistfour= {}

for index in ref:
    for issn in ajourfour:
        if issn == ref[index]:
            ranklistfour[index] = ajourfour[issn]
            
ranklistfour
# Out:
# {}

# %%
ref_rankd = refcs_or
ref_rankd["Rank1"] = pd.Series(ranklistone)
ref_rankd["Rank2"] = pd.Series(ranklisttwo)
ref_rankd["Rank3"] = pd.Series(ranklistthree)
ref_rankd["Rank4"] = pd.Series(ranklistfour)

ref_rankd.loc[ref_rankd['Rank1'].isnull(),'Rank1'] = ref_rankd['Rank2']
ref_rankd.loc[ref_rankd['Rank1'].isnull(),'Rank1'] = ref_rankd['Rank3']
ref_rankd.loc[ref_rankd['Rank1'].isnull(),'Rank1'] = ref_rankd['Rank4']

ref_rankd = ref_rankd.drop(["Rank2", "Rank3", "Rank4"], axis = 1)

count_nan = len(ref_rankd) - ref_rankd.count()

ref_rankd
# Out:
#          UKPRN                                        VolumeTitle      ISSN  \
# 0     10007760            Proceedings of the Aristotelian Society  00667374
# 1     10007760                    Minds, Ethics, and Conditionals       NaN
# 2     10007760                                           Synthese  00397857
# 3     10007760                              Prospects for Meaning       NaN
# 4     10007760  Knowing How: Essays on Knowledge, Mind, and Ac...       NaN
# 5     10007760                     Essays on Anscombe's Intention       NaN
# 6     10007760  Reason, Faith and History: Philosophical Essay...       NaN
# 7     10007760                                         Dialectica  00122017
# 8     10007760                                         Axiomathes  11221151
# 9     10007760                     Journal of Philosophical Logic  15730433
# 10    10007760                                               Mind  14602113
# 11    10007760                              Journal of Philosophy   0022362
# 12    10007760                        The Philosophical Quarterly  00318094
# 13    10007760                       The Review of Symbolic Logic  17550203
# 14    10007760                                           Synthese  00397857
# 15    10007760                                           Synthese  00397857
# 16    10007760                              Philosophical Studies  00318116
# 17    10007760                              Philosophical Studies  00318116
# 18    10007760                                                NaN       NaN
# 19    10007760                                                NaN       NaN
# 20    10007760                 Australasian Journal of Philosophy  00048402
# 21    10007760                                           Synthese  00397857
# 22    10007760          Aristotelian Society Supplementary Volume  03097013
# 23    10007760           Royal Institute of Philosophy Supplement  13582461
# 24    10007760                                           Synthese  00397857
# 25    10007760                                                NaN       NaN
# 26    10007760          Aristotelian Society Supplementary Volume  03097013
# 27    10007760         Spinoza's 'Theological-Political Treatise'       NaN
# 28    10007760  Understanding Counterfactuals, Understanding C...       NaN
# 29    10007760                  The British Journal of Aesthetics  14682842
# ...        ...                                                ...       ...
# 2143  10007814                                          Abstracta  18079792
# 2144  10007814                                                NaN       NaN
# 2145  10007814              Nietzsche, Naturalism and Normativity       NaN
# 2146  10007814                               Health Care Analysis  10653058
# 2147  10007814                               Health Care Analysis  10653058
# 2148  10007814                                          Cognition  00100277
# 2149  10007814                              Philosophical Studies  00318116
# 2150  10007814                              Philosophical Studies  00318116
# 2151  10007814                     European Journal of Philosophy  09668373
# 2152  10007814                                                NaN       NaN
# 2153  10007814                                                NaN       NaN
# 2154  10007814                                                NaN       NaN
# 2155  10007814                    Nietzsche and Political Thought       NaN
# 2156  10005343                          The Journal of Philosophy   0022362
# 2157  10005343                The Philosophy of International Law       NaN
# 2158  10005343                               Ethical Perspectives  13700049
# 2159  10005343                                  Religious Studies  00344125
# 2160  10005343                                           Synthese  00397857
# 2161  10005343                                 Law and Philosophy  01675249
# 2162  10005343                      Journal of Applied Philosophy  02643758
# 2163  10005343                      Journal of Applied Philosophy  02643758
# 2164  10005343                                          Bioethics  14678519
# 2165  10005343                      Journal of Applied Philosophy  02643758
# 2166  10005343                                         Philosophy  00318191
# 2167  10005343                  Ethical Theory and Moral Practice  13862820
# 2168  10005343                                           Synthese  00397857
# 2169  10005343  Procreation and Parenthood: The Ethics of Bear...       NaN
# 2170  10005343           Philosophy and Phenomenological Research  19331592
# 2171  10005343                Forgiveness: Probing the Boundaries       NaN
# 2172  10005343                              Philosophers' Imprint   1533628
#
#            Rank1
# 0            NaN
# 1            NaN
# 2             A*
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7              A
# 8            NaN
# 9             A*
# 10            A*
# 11            A*
# 12            A*
# 13    Not ranked
# 14            A*
# 15            A*
# 16            A*
# 17            A*
# 18           NaN
# 19           NaN
# 20            A*
# 21            A*
# 22           NaN
# 23           NaN
# 24            A*
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29            A*
# ...          ...
# 2143         NaN
# 2144         NaN
# 2145         NaN
# 2146           C
# 2147           C
# 2148          A*
# 2149          A*
# 2150          A*
# 2151          A*
# 2152         NaN
# 2153         NaN
# 2154         NaN
# 2155         NaN
# 2156          A*
# 2157         NaN
# 2158           C
# 2159           A
# 2160          A*
# 2161           A
# 2162           A
# 2163           A
# 2164          A*
# 2165           A
# 2166           A
# 2167           A
# 2168          A*
# 2169         NaN
# 2170          A*
# 2171         NaN
# 2172          A*
#
# [2173 rows x 4 columns]

# %%
totastar ={}
tota = {}
totb = {}
totc = {}
totjur = {}

totastara = {}

for index,row in ref_rankd.iterrows():
    if row["Rank1"] == "A*":
        if row["UKPRN"] not in totastar:
            totastar[row["UKPRN"]] = 1
        else:
            totastar[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totastar:
            totastar[row["UKPRN"]] = 0
    
    if row["Rank1"] == "A":
        if row["UKPRN"] not in tota:
            tota[row["UKPRN"]] = 1
        else:
            tota[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in tota:
            tota[row["UKPRN"]] = 0
            
    if row["Rank1"] == "B":
        if row["UKPRN"] not in totb:
            totb[row["UKPRN"]] = 1
        else:
            totb[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totb:
            totb[row["UKPRN"]] = 0
            
    if row["Rank1"] == "C":
        if row["UKPRN"] not in totc:
            totc[row["UKPRN"]] = 1
        else:
            totc[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totc:
            totc[row["UKPRN"]] = 0
        
    if row["UKPRN"] not in totjur:
        totjur[row["UKPRN"]] = 1
    else:
        totjur[row["UKPRN"]] += 1
        
    if row["Rank1"] == "A*" or row["Rank1"] == "A":
        if row["UKPRN"] not in totastara:
            totastara[row["UKPRN"]] = 1
        else:
            totastara[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totastara:
            totastara[row["UKPRN"]] = 0

# %%
## Now to add the four star rating
fourstr = pd.read_csv("REF2014Data_submissionprofile.csv")



fourstr = fourstr[fourstr["Profile"].str.contains("Outputs")]


fourstrdic = {}
threestrdic = {}
twostrdic = {}
onestrdic = {}

for index, row in fourstr.iterrows():
    fourstrdic[row["UKPRN"]] = row["FourStar"]
    threestrdic[row["UKPRN"]] = row["ThreeStar"]
    twostrdic[row["UKPRN"]] = row["TwoStar"]
    onestrdic[row["UKPRN"]] = row["OneStar"]

# %%
avastara = {}

for universityaa in totastara:
    for universitiesaa in totjur:
        if universitiesaa == universityaa:
            avastara[universitiesaa] = totastara[universityaa]/totjur[universitiesaa]*100

# %%
avastar = {}

for university in totastar:
    for universities in totjur:
        if universities == university:
            avastar[universities] = totastar[university]/totjur[universities]*100

# %%
ava = {}

for universitya in tota:
    for universitiesa in totjur:
        if universitiesa == universitya:
            ava[universitiesa] = tota[universitya]/totjur[universitiesa]*100

# %%
avb = {}

for universityb in totb:
    for universitiesb in totjur:
        if universitiesb == universityb:
            avb[universitiesb] = totb[universityb]/totjur[universitiesb]*100

# %%
avc = {}

for universityc in totc:
    for universitiesc in totjur:
        if universitiesc == universityc:
            avc[universitiesc] = totc[universityc]/totjur[universitiesc]*100

# %%
rankfoura = {}

for uniaa in fourstrdic:
    for unisaa in avastara:
        if unisaa == uniaa:
            rankfoura[avastara[unisaa]] = fourstrdic[uniaa]

# %%
rankfour = {}

for uni in fourstrdic:
    for unis in avastar:
        if unis == uni:
            rankfour[avastar[unis]] = fourstrdic[uni]

# %%
rankthree = {}

for unia in threestrdic:
    for unisa in ava:
        if unisa == unia:
            rankthree[ava[unisa]] = threestrdic[unia]

# %%
ranktwo = {}

for unib in twostrdic:
    for unisb in avb:
        if unisb == unib:
            ranktwo[avb[unisb]] = twostrdic[unib]

# %%
rankone = {}

for unic in onestrdic:
    for unisc in avc:
        if unisc == unic:
            rankone[avc[unisc]] = onestrdic[unic]

# %%
import matplotlib.pylab as plt
# %matplotlib inline

listsfa = sorted(rankfoura.items())
listsf = sorted(rankfour.items()) # sorted by key, return a list of tuples
listst = sorted(rankthree.items()) # sorted by key, return a list of tuples
liststw = sorted(ranktwo.items()) # sorted by key, return a list of tuples
listso = sorted(rankone.items()) # sorted by key, return a list of tuples

xastara,yastara = zip(*listsfa)
xastar, yastar = zip(*listsf) # unpack a list of pairs into two tuples
xa, ya = zip(*listst) # unpack a list of pairs into two tuples
xb, yb = zip(*liststw) # unpack a list of pairs into two tuples
xc, yc = zip(*listso) # unpack a list of pairs into two tuples


#plt.subplots(2,2, figsize = [16,10])
plt.figure(figsize = [16,10])
plt.plot(xastara,yastara, "bo")
plt.xlabel("Percentage of A* journals")#
plt.ylabel("Overall 4* Rating (as percentage)")
#plt.savefig("C vs 1star")

#plt.plot(xb,yb, "bo")
#plt.xlabel("Percentage of B journals")
#plt.ylabel("Overall 2* Rating (as percentage)")

#plt.subplots(2,2, figsize = [16,10])
#plt.plot(xa,ya, "bo")
#plt.xlabel("Percentage of A journals")
#plt.ylabel("Overall 3* Rating (as percentage)")
#plt.savefig("A vs 3star")

#plt.subplots(2,2, figsize = [16,10])
#plt.plot(xastar,yastar, "bo")
#plt.xlabel("Percentage of A* journals")#
#plt.ylabel("Overall 4* Rating (as percentage)")
#plt.savefig("Astar vs 4star")

# %%
from scipy.stats.stats import pearsonr

pearsonr(xastara,yastara)
# Out:
# (0.29710947431503909, 0.074133716904370942)
