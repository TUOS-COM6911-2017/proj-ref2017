# %%
import pandas as pd
import numpy as np
import difflib 

# Load impact ranking file
impact = pd.read_csv("journalimpact2014.csv")

# Remove unecessary columns
impact = impact.drop(impact.columns[5::], axis=1)


# Rename Issn --> ISSN  
impact = impact.rename(columns = {"Issn":"ISSN"})

# %%
# Keep the first ISSN and keep it in a new column
impact["ISSN1"] = impact.ISSN.str.replace(", .*", "")
impact["ISSN1"] = impact.ISSN1.str.replace("ISSN", "")
impact["ISSN1"] = impact.ISSN1.str.replace("X", "")
impact

# Keep the second ISSN if it appears in a new column and only keep unique values
impact["ISSN2"] = impact.ISSN.str.replace(".*, ", "")
impact["ISSN2"] = impact.ISSN2.str.replace("ISSN", "")
impact["ISSN2"] = impact.ISSN2.str.replace("X", "")

# to compare by name more normalising required

impact["Title"] = impact.Title.str.lower()
impact["Title"] = impact.Title.str.replace("-.*","")

impact
# Out:
#       Rank                                             Title     Type  \
# 0        1                           nature reviews genetics  journal
# 1        2                         nature reviews immunology  journal
# 2        3                             nature reviews cancer  journal
# 3        4             nature reviews molecular cell biology  journal
# 4        5                                   nature genetics  journal
# 5        6                                journal of finance  journal
# 6        7                                      econometrica  journal
# 7        8                                            nature  journal
# 8        9                             nature nanotechnology  journal
# 9       10                              nature biotechnology  journal
# 10      11                               nature cell biology  journal
# 11      12                                    nature methods  journal
# 12      13                      academy of management annals  journal
# 13      14                                  nature materials  journal
# 14      15                       nature reviews neuroscience  journal
# 15      16                                    nature physics  journal
# 16      17                                  nature photonics  journal
# 17      18                                 nature immunology  journal
# 18      19                          chemical society reviews  journal
# 19      20                        review of economic studies  journal
# 20      21                                        the lancet  journal
# 21      22                       review of financial studies  journal
# 22      23                               the lancet oncology  journal
# 23      24                       nature reviews microbiology  journal
# 24      25                               nature neuroscience  journal
# 25      26                    the lancet infectious diseases  journal
# 26      27                     progress in materials science  journal
# 27      28                               advances in physics  journal
# 28      29                              the lancet neurology  journal
# 29      30                                  nature chemistry  journal
# ...    ...                                               ...      ...
# 5447  5448                                        new design  journal
# 5448  5449                             cambridge law journal  journal
# 5449  5450                     animal technology and welfare  journal
# 5450  5451                                             opera  journal
# 5451  5452                        ecclesiastical law journal  journal
# 5452  5453                         steel times international  journal
# 5453  5454                      bulletin of hispanic studies  journal
# 5454  5455                            knitting international  journal
# 5455  5456                               occupational health  journal
# 5456  5457                                international dyer  journal
# 5457  5458                           hydrocarbon engineering  journal
# 5458  5459                                              epc   journal
# 5459  5460                    dairy industries international  journal
# 5460  5461  pharmaceutical manufacturing and packing sourcer  journal
# 5461  5462                      automotive engineer (london)  journal
# 5462  5463                                   mining magazine  journal
# 5463  5464              machinery and production engineering  journal
# 5464  5465                                            apollo  journal
# 5465  5466                              fire risk management  journal
# 5466  5467                                          engineer  journal
# 5467  5468                              architectural review  journal
# 5468  5469                          professional engineering  journal
# 5469  5470                                  food manufacture  journal
# 5470  5471                                           drapers  journal
# 5471  5472                                     dancing times  journal
# 5472  5473                                             strad  journal
# 5473  5474                             manufacturing chemist  journal
# 5474  5475                                 concrete (london)  journal
# 5475  5476                                              tls   journal
# 5476  5477                                   new electronics  journal
#
# 5473            ISSN 02624230   0.100   02624230   02624230
# 5474            ISSN 00105317   0.100   00105317   00105317
# 5475            ISSN 0307661X   0.100    0307661    0307661
# 5476            ISSN 00479624   0.100   00479624   00479624
#
# [5477 rows x 7 columns]

# %%
# Load the data output file
refcs_or = pd.read_csv("REF2014Data_output.csv")

## Keep only the volume title and ISSN number
refcs_or = refcs_or.drop(refcs_or.columns[[range(1,8)]], axis=1)
refcs_or = refcs_or.drop(refcs_or.columns[[range(2,7)]], axis=1)
refcs_or = refcs_or.drop(refcs_or.columns[3::], axis=1)
refcs_or["ISSN"] = refcs_or.ISSN.str.replace('X', '')
refcs_or["ISSN"] = refcs_or.ISSN.str.replace('-', '')

# to compare by name more normalising required

refcs_or["VolumeTitle"] = refcs_or.VolumeTitle.str.lower()
refcs_or["VolumeTitle"] = refcs_or.VolumeTitle.str.replace("-.*","")
refcopy = refcs_or

refcs_or
# Out:
#          UKPRN                                        VolumeTitle       ISSN
# 0     10007759                                          physica d   01672789
# 1     10007759                          computers and geosciences   00983004
# 2     10007759                   chemical biology and drug design   17470277
# 3     10007759       journal of chemical information and modeling   15499596
# 4     10007759                                             energy   03605442
# 5     10007759                          physiological measurement   09673334
# 6     10007759  international journal of digital crime and for...   19416210
# 7     10007759  communications in nonlinear science and numeri...   10075704
# 8     10007759                                           plos one   19326203
# 9     10007759                          computers and geosciences   00983004
# 10    10007759                                transactions in gis   13611682
# 11    10007759  journal of physics a: mathematical and theoret...   17518113
# 12    10007759  journal of physics a: mathematical and theoret...   17518113
# 13    10007759  journal of physics a: mathematical and theoret...   17518113
# 14    10007759  29th international conference on machine learning        NaN
# 15    10007759  journal of physics a: mathematical and theoret...   17518113
# 16    10007759                   journal of statistical mechanics   17425468
# 17    10007759                               information sciences   00200255
# 18    10007759  software engineering, artificial intelligence,...    1860949
# 19    10007759                     journal of statistical physics   00224715
# 20    10007759                            physical review letters   00319007
# 21    10007759                            physical review letters   00319007
# 22    10007759  ieee transactions on neural networks and learn...   10459227
# 23    10007759                               bmc medical genomics   17558794
# 24    10007759        journal of the optical society of america a   10847529
# 25    10007759                                          physica a   03784371
# 26    10007759                                  signal processing   01651684
# 27    10007759  journal of physics a: mathematical and theoret...   17518113
# 28    10007759        ieee transactions on biomedical engineering   00189294
# 29    10007759                                          interface   17425662
# ...        ...                                                ...        ...
# 7621  10007807                    robotics and autonomous systems    9218890
# 7622  10007807                       bioinspiration & biomimetics   17483190
# 7623  10007807                             biological cybernetics   14320770
# 7624  10007807                                  adaptive behavior   17412633
# 7625  10007807                  knowledge and information systems   02193116
# 7626  10007807                    pervasive and mobile computing    15741192
# 7627  10007807                  personal and ubiquitous computing   16174917
# 7628  10007807  ieee journal of biomedical and health informatics   21682208
# 7629  10007807       computer methods and programs in biomedicine    1692607
# 7630  10007807                       journal of electrocardiology   00220736
# 7631  10007807  ieee transactions on information technology in...   15580032
# 7632  10007807                     pervasive and mobile computing   15741192
# 7633  10007807  ieee transactions on information technology in...   10897771
# 7634  10007807                   journal of computational science   18777503
# 7635  10007807                      medical engineering & physics   13504533
# 7636  10007807                  journal of biomedical informatics   15320464
# 7637  10007807                       data & knowledge engineering    0169023
# 7638  10007807  journal of ambient intelligence andhumanized c...  18685137
# 7639  10007807  ieee transactions on information technology in...   10897771
# 7640  10007807  ieee/acm transactions on computational biology...   15455963
# 7641  10007807                                    ieee multimedia    1070986
# 7642  10007807                     pervasive and mobile computing   15741192
# 7643  10007807  ieee transactions on information technology in...   10897771
# 7644  10007807                       journal of electrocardiology     220736
# 7645  10007807                mathematical and computer modelling   08957177
# 7646  10007807                               nonlinear analysis b   14681218
# 7647  10007807                                 nonlinear dynamics   0924090
# 7648  10007807                               nonlinear analysis b   14681218
# 7649  10007807  ieee transactions on knowledge and data engine...   10414347
# 7650  10007807                      annals of telecommunications    00034347
#
# [7651 rows x 3 columns]

# %%
# Compile a dictionary of Volume title and Rank to merge by names
namerank = {}
for index, row in impact.iterrows():
    namerank[row["ISSN2"]] = row["SJR"]

# %%
# Compile a list of index from the REF data and volume title
reference = {}
for index, row in refcs_or.iterrows():
    reference[index] = row["ISSN"]

# %%
# Merge by name returning index location and ranking

indeximpact = {}
for index in reference:
    if reference[index] in namerank:
        indeximpact[index] = namerank[reference[index]]
        
len(indeximpact)
# Out:
# 226

# %%
refcopy["Rank1"] = pd.Series(indeximpact)

refcopy = refcopy.dropna()

# %%
## Find the average ranks to fill the nans with the mean ranks for each uni
sum_rank = {}
len_rank = {}

#for index, rows in av_rankd.iterrows():

for index, rows in refcopy.iterrows():
    if rows["UKPRN"] not in len_rank:
        len_rank[rows["UKPRN"]] = 1
    else:
        len_rank[rows["UKPRN"]] += 1
        
for index, rows in refcopy.iterrows():    
    if rows["UKPRN"] not in sum_rank:
        sum_rank[rows["UKPRN"]] = rows["Rank1"]
    else:
        sum_rank[rows["UKPRN"]] += rows["Rank1"]
        
av_rank = {}

for univd in len_rank:
    for univid in sum_rank:
        if univd == univid:
            av_rank[univd] = sum_rank[univd] / len_rank[univid]

# %%
#

indexlist = list()
rankinglist = list()

for index, row in refcopy.iterrows():
    for uniid in av_rank:
        if uniid == row["UKPRN"]:
            indexlist.append(uniid)
            rankinglist.append(av_rank[uniid])

# %%
## Now to create a dictionary with the average ranking per uni
unijourank = dict(zip(indexlist,rankinglist))

# %%
## Now to add the four star rating
fourstr = pd.read_csv("REF2014Data_submissionprofile.csv")



fourstr = fourstr[fourstr["Profile"].str.contains("Output")]
fourstr = fourstr.drop(fourstr.columns[[1,2,3,5,6,7,8]], axis=1)

fourstrdic = {}

for index, row in fourstr.iterrows():
    fourstrdic[row["UKPRN"]] = row["FourStar"]

# %%
rankfour = {}

for uni in fourstrdic:
    for unis in unijourank:
        if unis == uni:
            rankfour[unijourank[unis]] = fourstrdic[uni]

# %%
import matplotlib.pylab as plt
# %matplotlib inline

lists = sorted(rankfour.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.figure(figsize = [16,10])
plt.plot(x, y, "bo")
plt.xlabel("Average journal rank")
plt.ylabel("Impact 4* Rating (as percentage)")

plt.savefig("jpeg")
#plt.xscale('log')
#plt.yscale('log')

# %%
from scipy.stats.stats import pearsonr

pearsonr(x,y)
# Out:
# (0.091770148712418287, 0.45327978288697579)
