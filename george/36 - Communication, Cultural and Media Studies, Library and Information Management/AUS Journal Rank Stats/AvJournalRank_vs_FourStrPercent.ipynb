# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pickle
## Stats on Output and Citation

# Load and clean the output file
aujour_or = pd.read_csv("2010AJR.csv")

aujour_or = aujour_or.drop(aujour_or.columns[[0]], axis=1)
aujour_or = aujour_or.drop(aujour_or.columns[[range(2,8)]], axis=1)

# Normalise the ISSN numbersimport pandas as pd
aujour_or = aujour_or.rename(columns = {"Title":"VolumeTitle"})
aujour_or["ISSN1"] = aujour_or.ISSN1.str.replace('X', '')
aujour_or["ISSN2"] = aujour_or.ISSN2.str.replace('X', '')
aujour_or["ISSN3"] = aujour_or.ISSN3.str.replace('X', '')
aujour_or["ISSN4"] = aujour_or.ISSN4.str.replace('X', '')
aujour_or["ISSN1"] = aujour_or.ISSN1.str.replace('-', '')
aujour_or["ISSN2"] = aujour_or.ISSN2.str.replace('-', '')
aujour_or["ISSN3"] = aujour_or.ISSN3.str.replace('-', '')
aujour_or["ISSN4"] = aujour_or.ISSN4.str.replace('-', '')
aujour_or
# Out:
#       Rank                                        VolumeTitle     ISSN1  \
# 0        C                           1913: a journal of forms  15489914
# 1        B                                            3CMedia  18326161
# 2        C    4OR: A Quarterly Journal of Operations Research  16194500
# 3        C           A St A: Advances in Statistical Analysis  18638171
# 4        A  AA files: annals of the Architectural Associat...  02616823
# 5        B                    AACE International Transactions  15287106
# 6        B                                       AACE Journal  15513696
# 7        C                        AACN Advanced Critical Care  15597768
# 8        C                                       AANA Journal  00946354
# 9        C                                      AAOHN Journal  08910162
# 10       A                                      AAPG Bulletin  01491423
# 11       C                                       AAPS Journal  15507416
# 12       B                                  AAPS PharmSciTech  15309932
# 13       C     Aarboeger for Nordisk Oldkyndighed og Historie   0084585
# 14       C           AASA Journal of Scholarship and Practice  19316569
# 15       B                 ABA Journal: the lawyer's magazine  07470088
# 16       A  Abacus: a Journal of Accounting and Business S...  00013072
# 17       C                                  Abdominal Imaging  09428925
# 18       C       Abhandlungen fuer die Kunde des Morgenlandes  05674980
# 19       C  Aboriginal and Islander Health Worker Journal:...  10373403
# 20       B  Aboriginal and Torres Strait Islander Studies ...  13227157
# 21       A                                 Aboriginal History  03148769
# 22       A                                  About Performance  13246089
# 23       B                      Abstract and Applied Analysis  10853375
# 24       C                                            Academe  01902946
# 25       C  Academia de Stiinte a Republicii Moldova. Bule...  10247696
# 26       C                           Academia Economic Papers   1018161
# 27       C  Academia Paedagogica Nyiregyhaziensis. Acta Ma...  17860091
# 28       C    Academiae Scientiarum Hungarica. Acta Zoologica  12178837
# 29       B                        Academic Emergency Medicine  10696563
# ...    ...                                                ...       ...
# 20682    C  Zielsprache Deutsch: die Zeitschrift fuer den ...  03415864
# 20683    C          Zimbabwe Journal of Agricultural Research  02511045
# 20684    C           Zimbabwe Journal of Educational Research  10133445
# 20685    C                        Zimbabwe Veterinary Journal  10161511
# 20686    B                                             Zinbvn  00845515
# 20687    C                                        Ziva Antika  05147727
# 20688    A  ZNT - Zeitschrift fuer Neues Testament: das ne...  14352249
# 20689    B                                        Zoo Biology  07333188
# 20690    C                                       Zoocriaderos  07987811
# 20691    C  Zoologica Poloniae: Archivum Societatis Zoolog...   0044510
# 20692    B                                  Zoologica Scripta  03003256
# 20693    A          Zoological Journal of the Linnean Society  00244082
# 20694    B       Zoological Science: an international journal  02890003
# 20695    C                                 Zoological Studies  10215506
# 20696    C                              Zoologichesky Zhurnal  00445134
# 20697    C  Zoologisch-Botanische Gesellschaft in Oesterre...  02521911
# 20698    B                              Zoologischer Anzeiger  00445231
# 20699    B                                            Zoology  09442006
# 20700    C                         Zoology in the Middle East  09397140
# 20701    B  Zoomorphology: an international journal of com...   0720213
# 20702    B                         Zoonoses and Public Health  18631959
# 20703    C  Zoosystematics and Evolution: Mitteilungen aus...  14351935
# 20704    C                                            Zootaxa  11755326
# 20705    C                              Zpravy Pamatkove Pece  12105538
# 20706    C                                     Zuchtungskunde  00445401
# 20707    C                                 Zuckmayer-Jahrbuch  14347865
# 20708    C                                       Zuowu Xuebao  04963490
# 20709    B                                         Zwingliana  02544407
# 20710    A             Zygon: journal of religion and science  05912385
# 20711    C   Zygote: the biology of gametes and early embryos  09671994
#
#           ISSN2     ISSN3     ISSN4
# 0           NaN       NaN       NaN
# 1       1445971       NaN       NaN
# 2      03908127       NaN       NaN
# 3       1863818  00026018       NaN
# 4           NaN       NaN       NaN
# 5           NaN       NaN       NaN
# 6           NaN       NaN       NaN
# 7      15597776  10790713       NaN
# 8           NaN       NaN       NaN
# 9           NaN       NaN       NaN
# 10     15589153       NaN       NaN
# 11          NaN       NaN       NaN
# 12          NaN       NaN       NaN
# 13          NaN       NaN       NaN
# 14      0898252       NaN       NaN
# 15          NaN       NaN       NaN
# 16     14676281       NaN       NaN
# 17     03642356       NaN       NaN
# 18          NaN       NaN       NaN
# 19          NaN       NaN       NaN
# 20          NaN       NaN       NaN
# 21          NaN       NaN       NaN
# 22          NaN       NaN       NaN
# 23     16870409       NaN       NaN
# 24          NaN       NaN       NaN
# 25     02363089       NaN       NaN
# 26          NaN       NaN       NaN
# 27     08660182       NaN       NaN
# 28     02367130  00017264       NaN
# 29     15532712       NaN       NaN
# ...         ...       ...       ...
# 20682       NaN       NaN       NaN
# 20683  00354813       NaN       NaN
# 20684       NaN       NaN       NaN
# 20685       NaN       NaN       NaN
# 20686       NaN       NaN       NaN
# 20687       NaN       NaN       NaN
# 20688       NaN       NaN       NaN
# 20689  10982361       NaN       NaN
# 20690       NaN       NaN       NaN
# 20691       NaN       NaN       NaN
# 20692  14636409       NaN       NaN
# 20693  10963642       NaN       NaN
# 20694       NaN       NaN       NaN
# 20695  00013943       NaN       NaN
# 20696  00138738       NaN       NaN
# 20697       NaN       NaN       NaN
# 20698  18732674  00445193       NaN
# 20699  18732720       NaN       NaN
# 20700       NaN       NaN       NaN
# 20701   1432234       NaN       NaN
# 20702  18632378  09311793  09314229
# 20703  18600743  02325519  03738493
# 20704  11755334       NaN       NaN
# 20705       NaN       NaN       NaN
# 20706       NaN       NaN       NaN
# 20707  01771183       NaN       NaN
# 20708       NaN       NaN       NaN
# 20709       NaN       NaN       NaN
# 20710  14679744       NaN       NaN
# 20711  14698730       NaN       NaN
#
# [20712 rows x 6 columns]

# %%
# Load the journal names from the UOA and their ISSNs
refcs_or = pd.read_csv("REF2014Data_output.csv")

# Clean the data
refcs_or = refcs_or.drop(refcs_or.columns[[range(1,8)]], axis=1)
refcs_or = refcs_or.drop(refcs_or.columns[[range(2,7)]], axis=1)
refcs_or = refcs_or.drop(refcs_or.columns[3::], axis=1)
refcs_or["ISSN"] = refcs_or.ISSN.str.replace('X', '')
refcs_or["ISSN"] = refcs_or.ISSN.str.replace('-', '')

refcs_or
# Out:
#          UKPRN                                        VolumeTitle      ISSN
# 0     10000291               European Journal of Cultural Studies  14603551
# 1     10000291                                                NaN       NaN
# 2     10000291  Northern Ireland After the Troubles: A Society...       NaN
# 3     10000291                                                NaN       NaN
# 4     10000291                                   Culture Machine   14654121
# 5     10000291         International Public Policy Review Journal  17485207
# 6     10000291                                                NaN       NaN
# 7     10000291                                                NaN       NaN
# 8     10000291                                Rape in Art Cinema        NaN
# 9     10000291                       Contemporary Women's Writing  17541476
# 10    10000291                                                NaN       NaN
# 11    10000291          New Review of Film and Television Studies  17407923
# 12    10000291        Contemporary French and Francophone Studies  17409306
# 13    10000291          New Cinemas: Journal of Contemporary Film  20400578
# 14    10000291                                                NaN       NaN
# 15    10000291                                                NaN       NaN
# 16    10000291                                     New Formations  17410789
# 17    10000291                                                NaN       NaN
# 18    10000291                                                NaN       NaN
# 19    10000291             Journal of Popular Film and Television  19306458
# 20    10000291         The Cultural Identities of European Cities       NaN
# 21    10000291  México 2010 Kultur in Bewegung - Mythen auf de...       NaN
# 22    10000291  Carnal Knowledge: Towards a 'New Materialism' ...       NaN
# 23    10000291                                Sonic Interventions       NaN
# 24    10000291          Sonic Mediations: Body, Sound, Technology       NaN
# 25    10000291         NECSUS - European Journal of Media Studies  22130217
# 26    10000291                                                NaN       NaN
# 27    10000291                                                NaN       NaN
# 28    10000291                            Immigrants & Minorities  17440521
# 29    10000291            Journal of Ethnic and Migration Studies  14699451
# ...        ...                                                ...       ...
# 3487  10007807                                                NaN       NaN
# 3488  10007807                       Early Popular Visual Culture  17460662
# 3489  10007807           Journal of British Cinema and Television  17434521
# 3490  10007807                              Popular Music History  17431646
# 3491  10007807                              Specialist Journalism       NaN
# 3492  10007807                                                NaN       NaN
# 3493  10007807                   Journal of Language and Politics  15692159
# 3494  10007807                      Gender and Spoken Interaction       NaN
# 3495  10007807   Treat or trick? Halloween in a Globalising World       NaN
# 3496  10007807                              The Media in Scotland       NaN
# 3497  10007807                            The Political Quarterly  00323179
# 3498  10007807                                                NaN       NaN
# 3499  10007807                                                NaN       NaN
# 3500  10007807                                                NaN       NaN
# 3501  10007807                                                NaN       NaN
# 3502  10007807  Truth, Dare or Promise: Art and Documentary Re...       NaN
# 3503  10007807                     The Centrifugal Book of Europe       NaN
# 3504  10007807                                                NaN       NaN
# 3505  10007807                                                NaN       NaN
# 3506  10007807                                                NaN       NaN
# 3507  10007807                                                NaN       NaN
# 3508  10007807     The Ashgate Research Companion to Moral Panics       NaN
# 3509  10007807                                                NaN       NaN
# 3510  10007807  Gender and Public Relations: Critical perspect...       NaN
# 3511  10007807       The Edinburgh Companion to Poststructuralism       NaN
# 3512  10007807                        Language, Society and Power       NaN
# 3513  10007807                                                NaN       NaN
# 3514  10007807  Content Cultures: Transformations of User Gene...       NaN
# 3515  10007807                        Irish Communications Review       NaN
# 3516  10007807                             The War Body on Screen       NaN
#
# [3517 rows x 3 columns]

# %%
# create a dictionary of indexed ISSNs
ref = {}
for index, row in refcs_or.iterrows():
    indexs = index
    ref[index] = row["ISSN"]
ref.get(7647)

# %%
# Retrieve all the ISSNs from the Australian journals into one ISSN column
ajourone = {}
for index, row in aujour_or.iterrows():
    ajourone[row["ISSN1"]] = row["Rank"]

# %%
ajourtwo = {}
for index, row in aujour_or.iterrows():
    ajourtwo[row["ISSN2"]] = row["Rank"]

len(ajourtwo)
# Out:
# 11416

# %%
ajourthree = {}
for index, row in aujour_or.iterrows():
    ajourthree[row["ISSN3"]] = row["Rank"]

# %%
ajourfour = {}
for index, row in aujour_or.iterrows():
    ajourfour[row["ISSN4"]] = row["Rank"]

# %%
# Merge Australian journal ranks with UOA data by ISSN
ranklistone = {}

for index in ref:
    for issn in ajourone:
        if issn == ref[index]:
            ranklistone[index] = ajourone[issn]

# %%
ranklisttwo = {}

for index in ref:
    for issn in ajourtwo:
        if issn == ref[index]:
            ranklisttwo[index] = ajourtwo[issn]

# %%
ranklistthree = {}

for index in ref:
    for issn in ajourthree:
        if issn == ref[index]:
            ranklistthree[index] = ajourthree[issn]

# %%
ranklistfour= {}

for index in ref:
    for issn in ajourfour:
        if issn == ref[index]:
            ranklistfour[index] = ajourfour[issn]

# %%
ref_rankd = refcs_or
ref_rankd["Rank1"] = pd.Series(ranklistone)
ref_rankd["Rank2"] = pd.Series(ranklisttwo)
ref_rankd["Rank3"] = pd.Series(ranklistthree)
ref_rankd["Rank4"] = pd.Series(ranklistfour)


ref_rankd.loc[ref_rankd['Rank1'].isnull(),'Rank1'] = ref_rankd['Rank2']
ref_rankd.loc[ref_rankd['Rank1'].isnull(),'Rank1'] = ref_rankd['Rank3']
ref_rankd.loc[ref_rankd['Rank1'].isnull(),'Rank1'] = ref_rankd['Rank4']

ref_rankd = ref_rankd.drop(["Rank2", "Rank3", "Rank4"], axis = 1)

count_nan = len(ref_rankd) - ref_rankd.count()

refranking = ref_rankd

ref_rankd
# Out:
#          UKPRN                                        VolumeTitle      ISSN  \
# 0     10000291               European Journal of Cultural Studies  14603551
# 1     10000291                                                NaN       NaN
# 2     10000291  Northern Ireland After the Troubles: A Society...       NaN
# 3     10000291                                                NaN       NaN
# 4     10000291                                   Culture Machine   14654121
# 5     10000291         International Public Policy Review Journal  17485207
# 6     10000291                                                NaN       NaN
# 7     10000291                                                NaN       NaN
# 8     10000291                                Rape in Art Cinema        NaN
# 9     10000291                       Contemporary Women's Writing  17541476
# 10    10000291                                                NaN       NaN
# 11    10000291          New Review of Film and Television Studies  17407923
# 12    10000291        Contemporary French and Francophone Studies  17409306
# 13    10000291          New Cinemas: Journal of Contemporary Film  20400578
# 14    10000291                                                NaN       NaN
# 15    10000291                                                NaN       NaN
# 16    10000291                                     New Formations  17410789
# 17    10000291                                                NaN       NaN
# 18    10000291                                                NaN       NaN
# 19    10000291             Journal of Popular Film and Television  19306458
# 20    10000291         The Cultural Identities of European Cities       NaN
# 21    10000291  México 2010 Kultur in Bewegung - Mythen auf de...       NaN
# 22    10000291  Carnal Knowledge: Towards a 'New Materialism' ...       NaN
# 23    10000291                                Sonic Interventions       NaN
# 24    10000291          Sonic Mediations: Body, Sound, Technology       NaN
# 25    10000291         NECSUS - European Journal of Media Studies  22130217
# 26    10000291                                                NaN       NaN
# 27    10000291                                                NaN       NaN
# 28    10000291                            Immigrants & Minorities  17440521
# 29    10000291            Journal of Ethnic and Migration Studies  14699451
# ...        ...                                                ...       ...
# 3487  10007807                                                NaN       NaN
# 3488  10007807                       Early Popular Visual Culture  17460662
# 3489  10007807           Journal of British Cinema and Television  17434521
# 3490  10007807                              Popular Music History  17431646
# 3491  10007807                              Specialist Journalism       NaN
# 3492  10007807                                                NaN       NaN
# 3493  10007807                   Journal of Language and Politics  15692159
# 3494  10007807                      Gender and Spoken Interaction       NaN
# 3495  10007807   Treat or trick? Halloween in a Globalising World       NaN
# 3496  10007807                              The Media in Scotland       NaN
# 3497  10007807                            The Political Quarterly  00323179
# 3498  10007807                                                NaN       NaN
# 3499  10007807                                                NaN       NaN
# 3500  10007807                                                NaN       NaN
# 3501  10007807                                                NaN       NaN
# 3502  10007807  Truth, Dare or Promise: Art and Documentary Re...       NaN
# 3503  10007807                     The Centrifugal Book of Europe       NaN
# 3504  10007807                                                NaN       NaN
# 3505  10007807                                                NaN       NaN
# 3506  10007807                                                NaN       NaN
# 3507  10007807                                                NaN       NaN
# 3508  10007807     The Ashgate Research Companion to Moral Panics       NaN
# 3509  10007807                                                NaN       NaN
# 3510  10007807  Gender and Public Relations: Critical perspect...       NaN
# 3511  10007807       The Edinburgh Companion to Poststructuralism       NaN
# 3512  10007807                        Language, Society and Power       NaN
# 3513  10007807                                                NaN       NaN
# 3514  10007807  Content Cultures: Transformations of User Gene...       NaN
# 3515  10007807                        Irish Communications Review       NaN
# 3516  10007807                             The War Body on Screen       NaN
#
#      Rank1
# 0        A
# 1      NaN
# 2      NaN
# 3      NaN
# 4        B
# 5        C
# 6      NaN
# 7      NaN
# 8      NaN
# 9        A
# 10     NaN
# 11       A
# 12       A
# 13       B
# 14     NaN
# 15     NaN
# 16       A
# 17     NaN
# 18     NaN
# 19       B
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28       C
# 29       B
# ...    ...
# 3487   NaN
# 3488     B
# 3489     A
# 3490   NaN
# 3491   NaN
# 3492   NaN
# 3493     B
# 3494   NaN
# 3495   NaN
# 3496   NaN
# 3497     B
# 3498   NaN
# 3499   NaN
# 3500   NaN
# 3501   NaN
# 3502   NaN
# 3503   NaN
# 3504   NaN
# 3505   NaN
# 3506   NaN
# 3507   NaN
# 3508   NaN
# 3509   NaN
# 3510   NaN
# 3511   NaN
# 3512   NaN
# 3513   NaN
# 3514   NaN
# 3515   NaN
# 3516   NaN
#
# [3517 rows x 4 columns]

# %%
# Assign a score to the ranks
ref_rankd = ref_rankd.replace("A*", 4)
ref_rankd = ref_rankd.replace("A", 3)
ref_rankd = ref_rankd.replace("B", 2)
ref_rankd = ref_rankd.replace("C", 1)
ref_rankd = ref_rankd.replace("Not ranked",0)
ref_rankd
# Out:
#          UKPRN                                        VolumeTitle      ISSN  \
# 0     10000291               European Journal of Cultural Studies  14603551
# 1     10000291                                                NaN       NaN
# 2     10000291  Northern Ireland After the Troubles: A Society...       NaN
# 3     10000291                                                NaN       NaN
# 4     10000291                                   Culture Machine   14654121
# 5     10000291         International Public Policy Review Journal  17485207
# 6     10000291                                                NaN       NaN
# 7     10000291                                                NaN       NaN
# 8     10000291                                Rape in Art Cinema        NaN
# 9     10000291                       Contemporary Women's Writing  17541476
# 10    10000291                                                NaN       NaN
# 11    10000291          New Review of Film and Television Studies  17407923
# 12    10000291        Contemporary French and Francophone Studies  17409306
# 13    10000291          New Cinemas: Journal of Contemporary Film  20400578
# 14    10000291                                                NaN       NaN
# 15    10000291                                                NaN       NaN
# 16    10000291                                     New Formations  17410789
# 17    10000291                                                NaN       NaN
# 18    10000291                                                NaN       NaN
# 19    10000291             Journal of Popular Film and Television  19306458
# 20    10000291         The Cultural Identities of European Cities       NaN
# 21    10000291  México 2010 Kultur in Bewegung - Mythen auf de...       NaN
# 22    10000291  Carnal Knowledge: Towards a 'New Materialism' ...       NaN
# 23    10000291                                Sonic Interventions       NaN
# 24    10000291          Sonic Mediations: Body, Sound, Technology       NaN
# 25    10000291         NECSUS - European Journal of Media Studies  22130217
# 26    10000291                                                NaN       NaN
# 27    10000291                                                NaN       NaN
# 28    10000291                            Immigrants & Minorities  17440521
# 29    10000291            Journal of Ethnic and Migration Studies  14699451
# ...        ...                                                ...       ...
# 3487  10007807                                                NaN       NaN
# 3488  10007807                       Early Popular Visual Culture  17460662
# 3489  10007807           Journal of British Cinema and Television  17434521
# 3490  10007807                              Popular Music History  17431646
# 3491  10007807                              Specialist Journalism       NaN
# 3492  10007807                                                NaN       NaN
# 3493  10007807                   Journal of Language and Politics  15692159
# 3494  10007807                      Gender and Spoken Interaction       NaN
# 3495  10007807   Treat or trick? Halloween in a Globalising World       NaN
# 3496  10007807                              The Media in Scotland       NaN
# 3497  10007807                            The Political Quarterly  00323179
# 3498  10007807                                                NaN       NaN
# 3499  10007807                                                NaN       NaN
# 3500  10007807                                                NaN       NaN
# 3501  10007807                                                NaN       NaN
# 3502  10007807  Truth, Dare or Promise: Art and Documentary Re...       NaN
# 3503  10007807                     The Centrifugal Book of Europe       NaN
# 3504  10007807                                                NaN       NaN
# 3505  10007807                                                NaN       NaN
# 3506  10007807                                                NaN       NaN
# 3507  10007807                                                NaN       NaN
# 3508  10007807     The Ashgate Research Companion to Moral Panics       NaN
# 3509  10007807                                                NaN       NaN
# 3510  10007807  Gender and Public Relations: Critical perspect...       NaN
# 3511  10007807       The Edinburgh Companion to Poststructuralism       NaN
# 3512  10007807                        Language, Society and Power       NaN
# 3513  10007807                                                NaN       NaN
# 3514  10007807  Content Cultures: Transformations of User Gene...       NaN
# 3515  10007807                        Irish Communications Review       NaN
# 3516  10007807                             The War Body on Screen       NaN
#
#       Rank1
# 0       3.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       2.0
# 5       1.0
# 6       NaN
# 7       NaN
# 8       NaN
# 9       3.0
# 10      NaN
# 11      3.0
# 12      3.0
# 13      2.0
# 14      NaN
# 15      NaN
# 16      3.0
# 17      NaN
# 18      NaN
# 19      2.0
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      1.0
# 29      2.0
# ...     ...
# 3487    NaN
# 3488    2.0
# 3489    3.0
# 3490    NaN
# 3491    NaN
# 3492    NaN
# 3493    2.0
# 3494    NaN
# 3495    NaN
# 3496    NaN
# 3497    2.0
# 3498    NaN
# 3499    NaN
# 3500    NaN
# 3501    NaN
# 3502    NaN
# 3503    NaN
# 3504    NaN
# 3505    NaN
# 3506    NaN
# 3507    NaN
# 3508    NaN
# 3509    NaN
# 3510    NaN
# 3511    NaN
# 3512    NaN
# 3513    NaN
# 3514    NaN
# 3515    NaN
# 3516    NaN
#
# [3517 rows x 4 columns]

# %%
## Find the average ranks to fill the nans with the mean ranks for each uni
sum_rank = {}
len_rank = {}

rref = ref_rankd.dropna()

#for index, rows in av_rankd.iterrows():

for index, rows in rref.iterrows():
    if rows["UKPRN"] not in len_rank:
        len_rank[rows["UKPRN"]] = 1
    else:
        len_rank[rows["UKPRN"]] += 1
        
for index, rows in rref.iterrows():    
    if rows["UKPRN"] not in sum_rank:
        sum_rank[rows["UKPRN"]] = rows["Rank1"]
    else:
        sum_rank[rows["UKPRN"]] += rows["Rank1"]
        
av_rank = {}

for univd in len_rank:
    for univid in sum_rank:
        if univd == univid:
            av_rank[univd] = sum_rank[univd] / len_rank[univid]

# %%
indexlist = list()
rankinglist = list()

for index, row in ref_rankd.iterrows():
    for uniid in av_rank:
        if uniid == row["UKPRN"]:
            indexlist.append(uniid)
            rankinglist.append(av_rank[uniid])

# %%
ref_rankd["Rank1"] = pd.Series(rankinglist)

# %%
## This is the normalised ref_rankd
#ref_rankd = ref_rankd.drop(["Rank1"], axis = 1)

ref_rankd
# Out:
#          UKPRN                                        VolumeTitle      ISSN  \
# 0     10000291               European Journal of Cultural Studies  14603551
# 1     10000291                                                NaN       NaN
# 2     10000291  Northern Ireland After the Troubles: A Society...       NaN
# 3     10000291                                                NaN       NaN
# 4     10000291                                   Culture Machine   14654121
# 5     10000291         International Public Policy Review Journal  17485207
# 6     10000291                                                NaN       NaN
# 7     10000291                                                NaN       NaN
# 8     10000291                                Rape in Art Cinema        NaN
# 9     10000291                       Contemporary Women's Writing  17541476
# 10    10000291                                                NaN       NaN
# 11    10000291          New Review of Film and Television Studies  17407923
# 12    10000291        Contemporary French and Francophone Studies  17409306
# 13    10000291          New Cinemas: Journal of Contemporary Film  20400578
# 14    10000291                                                NaN       NaN
# 15    10000291                                                NaN       NaN
# 16    10000291                                     New Formations  17410789
# 17    10000291                                                NaN       NaN
# 18    10000291                                                NaN       NaN
# 19    10000291             Journal of Popular Film and Television  19306458
# 20    10000291         The Cultural Identities of European Cities       NaN
# 21    10000291  México 2010 Kultur in Bewegung - Mythen auf de...       NaN
# 22    10000291  Carnal Knowledge: Towards a 'New Materialism' ...       NaN
# 23    10000291                                Sonic Interventions       NaN
# 24    10000291          Sonic Mediations: Body, Sound, Technology       NaN
# 25    10000291         NECSUS - European Journal of Media Studies  22130217
# 26    10000291                                                NaN       NaN
# 27    10000291                                                NaN       NaN
# 28    10000291                            Immigrants & Minorities  17440521
# 29    10000291            Journal of Ethnic and Migration Studies  14699451
# ...        ...                                                ...       ...
# 3487  10007807                                                NaN       NaN
# 3488  10007807                       Early Popular Visual Culture  17460662
# 3489  10007807           Journal of British Cinema and Television  17434521
# 3490  10007807                              Popular Music History  17431646
# 3491  10007807                              Specialist Journalism       NaN
# 3492  10007807                                                NaN       NaN
# 3493  10007807                   Journal of Language and Politics  15692159
# 3494  10007807                      Gender and Spoken Interaction       NaN
# 3495  10007807   Treat or trick? Halloween in a Globalising World       NaN
# 3496  10007807                              The Media in Scotland       NaN
# 3497  10007807                            The Political Quarterly  00323179
# 3498  10007807                                                NaN       NaN
# 3499  10007807                                                NaN       NaN
# 3500  10007807                                                NaN       NaN
# 3501  10007807                                                NaN       NaN
# 3502  10007807  Truth, Dare or Promise: Art and Documentary Re...       NaN
# 3503  10007807                     The Centrifugal Book of Europe       NaN
# 3504  10007807                                                NaN       NaN
# 3505  10007807                                                NaN       NaN
# 3506  10007807                                                NaN       NaN
# 3507  10007807                                                NaN       NaN
# 3508  10007807     The Ashgate Research Companion to Moral Panics       NaN
# 3509  10007807                                                NaN       NaN
# 3510  10007807  Gender and Public Relations: Critical perspect...       NaN
# 3511  10007807       The Edinburgh Companion to Poststructuralism       NaN
# 3512  10007807                        Language, Society and Power       NaN
# 3513  10007807                                                NaN       NaN
# 3514  10007807  Content Cultures: Transformations of User Gene...       NaN
# 3515  10007807                        Irish Communications Review       NaN
# 3516  10007807                             The War Body on Screen       NaN
#
#          Rank1
# 0     2.153846
# 1     2.153846
# 2     2.153846
# 3     2.153846
# 4     2.153846
# 5     2.153846
# 6     2.153846
# 7     2.153846
# 8     2.153846
# 9     2.153846
# 10    2.153846
# 11    2.153846
# 12    2.153846
# 13    2.153846
# 14    2.153846
# 15    2.153846
# 16    2.153846
# 17    2.153846
# 18    2.153846
# 19    2.153846
# 20    2.153846
# 21    2.153846
# 22    2.153846
# 23    2.153846
# 24    2.153846
# 25    2.153846
# 26    2.153846
# 27    2.153846
# 28    2.153846
# 29    2.153846
# ...        ...
# 3487  1.875000
# 3488  1.875000
# 3489  1.875000
# 3490  1.875000
# 3491  1.875000
# 3492  1.875000
# 3493  1.875000
# 3494  1.875000
# 3495  1.875000
# 3496  1.875000
# 3497  1.875000
# 3498  1.875000
# 3499  1.875000
# 3500  1.875000
# 3501  1.875000
# 3502  1.875000
# 3503  1.875000
# 3504  1.875000
# 3505  1.875000
# 3506  1.875000
# 3507  1.875000
# 3508  1.875000
# 3509  1.875000
# 3510  1.875000
# 3511  1.875000
# 3512  1.875000
# 3513  1.875000
# 3514  1.875000
# 3515  1.875000
# 3516  1.875000
#
# [3517 rows x 4 columns]

# %%
## Now to create a dictionary with the average ranking per uni
unijourank = dict(zip(indexlist,rankinglist))

#with open("univ_journrank_physics.pkl", 'wb') as handle:
 #   pickle.dump(unijourank, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
## Now to add the four star rating
fourstr = pd.read_csv("REF2014Data_submissionprofile.csv")



fourstr = fourstr[fourstr["Profile"].str.contains("Outputs")]
fourstr = fourstr.drop(fourstr.columns[[1,2,3,5,6,7,8]], axis=1)

fourstrdic = {}

for index, row in fourstr.iterrows():
    fourstrdic[row["UKPRN"]] = row["FourStar"]
    
#with open("univ_fourstr_physics.pkl", 'wb') as handle:
 #   pickle.dump(fourstrdic, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
rankfour = {}

for uni in fourstrdic:
    for unis in unijourank:
        if unis == uni:
            rankfour[unijourank[unis]] = fourstrdic[uni]

# %%
import matplotlib.pylab as plt
# %matplotlib inline

lists = sorted(rankfour.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.figure(figsize = [16,10])
plt.plot(x, y, "bo")
plt.xlabel("Average journal rank")
plt.ylabel("Overall 4* Rating (as percentage)")

#plt.savefig("jpeg")

# %%
from scipy.stats.stats import pearsonr

pearsonr(x,y)
# Out:
# (0.50666866616157702, 7.909872159780864e-05)

# %%
########### FUTHER ANALYSIS TO CLARIFY RESULTS ###############

totastar = {}
tota = {}
totb = {}
totc = {}

for index,row in refranking.iterrows():
    if row["Rank1"] == "A*":
        if row["UKPRN"] not in totastar:
            totastar[row["UKPRN"]] = 1
        else:
            totastar[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totastar:
            totastar[row["UKPRN"]] = 0
            
    if row["Rank1"] == "A":
        if row["UKPRN"] not in tota:
            tota[row["UKPRN"]] = 1
        else:
            tota[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in tota:
            tota[row["UKPRN"]] = 0
            
    if row["Rank1"] == "B":
        if row["UKPRN"] not in totb:
            totb[row["UKPRN"]] = 1
        else:
            totb[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totb:
            totb[row["UKPRN"]] = 0
            
    if row["Rank1"] == "C":
        if row["UKPRN"] not in totc:
            totc[row["UKPRN"]] = 1
        else:
            totc[row["UKPRN"]] += 1
    else:
        if row["UKPRN"] not in totc:
            totc[row["UKPRN"]] = 0

# %%
dataframe  = pd.DataFrame.from_dict(totastar, orient = "index")

# %%
dataframe = dataframe.rename(columns = {0:"A*"})

# %%
totalist = tuple(tota.items())
totblist = tuple(totb.items())
totclist = tuple(totc.items())
totuni = tuple(unijourank.items())
unifour = tuple(fourstrdic.items())

x, totalisty = zip(*totalist)
x, totblisty = zip(*totblist)
x, totclisty = zip(*totclist)
x, totuniy = zip(*totuni)
x, unifoury = zip(*unifour)

# %%
dataframe["A"] = pd.Series(totalisty).values
dataframe["B"] = pd.Series(totblisty).values
dataframe["C"] = pd.Series(totclisty).values
dataframe["Av. Rank"] = pd.Series(totuniy).values
dataframe["Four Str"] = pd.Series(unifoury).values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-ad258bdf4b14> in <module>()
#       3 dataframe["C"] = pd.Series(totclisty).values
#       4 dataframe["Av. Rank"] = pd.Series(totuniy).values
# ----> 5 dataframe["Four Str"] = pd.Series(unifoury).values
#       6
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# -> 2568             value = _sanitize_index(value, self.index, copy=False)
#    2569             if not isinstance(value, (np.ndarray, Index)):
#    2570                 if isinstance(value, list) and len(value) > 0:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    2877
#    2878     if len(data) != len(index):
# -> 2879         raise ValueError('Length of values does not match length of ' 'index')
#    2880
#    2881     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
dataframe = dataframe.rename(columns = {0:"A*"})
dataframe.to_csv("General Stats.csv")

# %%
x = dataframe["Av. Rank"] 
y = dataframe["Four Str"]
z = dataframe.index

fig, ax = plt.subplots()
ax.plot(x, y, 'bo')
fig.set_size_inches(18.5, 10.5)

for X, Y, Z in zip(x, y, z):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(Z), xy=(X,Y), xytext=(-5, 5), ha='right',
                textcoords='offset points')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Four Str'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-756062c6d7d9> in <module>()
#       1
#       2 x = dataframe["Av. Rank"]
# ----> 3 y = dataframe["Four Str"]
#       4 z = dataframe.index
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Four Str'

# %%
dataframe = dataframe.sort_values("Av. Rank")

dataframe
#dataframe.to_csv("General Stats.csv")
# Out:
#            A*   A   B  C  Av. Rank  Four Str
# 10000961   19  51  14  9  2.860215       2.0
# 10007150   13  46  12  1  2.986111       2.5
# 10007760   29  37  15  4  3.070588      10.3
# 10007783   13  39   4  1  3.122807       4.8
# 10006840   31  33   9  2  3.240000       7.6
# 10001478   25  18   7  2  3.269231      16.7
# 10007806   16  27   3  0  3.282609      14.8
# 10007157   18  32   0  0  3.360000       8.0
# 10007798   51  45   5  4  3.361905      11.4
# 10007167   54  40   4  5  3.388350      14.4
# 10007158   33  30   3  1  3.439394      22.0
# 10007796   39  32   4  0  3.466667      18.8
# 10007803   22  13   0  2  3.486486      23.5
# 10007792   38  29   2  0  3.521739      13.3
# 10007790   23  10   3  0  3.555556      30.9
# 10007789   27  21   0  0  3.562500      20.4
# 10007154   77  43   1  2  3.585366      19.7
# 10007786   36  14   4  0  3.592593      22.2
# 10007794   61  16   1  4  3.634146      18.1
# 10007775   66  17   1  4  3.647727      20.2
# 10007774  149  48   7  2  3.669903      42.6
# 10007160   49  19   1  0  3.695652      26.8
# 10007163   92  18   1  2  3.769912      42.6
# 10007791   74  21   0  0  3.778947      29.2
# 10007788   70  15   1  0  3.802326      54.5
# 10005553   43   5   1  0  3.857143      35.3
# 10007784  102  13   1  0  3.870690      69.7
# 10004063  123  18   0  0  3.872340      56.3

# %%
tot_astar = dataframe["A*"].sum()
tot_a = dataframe["A"].sum()
tot_b = dataframe["B"].sum()
tot_c = dataframe["C"].sum()

# %%
print(tot_astar, tot_a, tot_b, tot_c)
# Out:
# 1393 750 104 45
